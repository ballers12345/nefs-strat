# %% [markdown]
# # NEFS Technology Division - Algorithmic Trading Project Template

# %% [markdown]
# ### Description
#
# As a group, you have been tasked with researching, implementing and testing a profitable Foreign Exchange (Forex) trading strategy. The pair you have been assigned is GBP/USD.
#
# Each group will have a number of Quants, Software Engineers and Product Managers. You will need to work as a team to allocate responsibilities for the duration of the project. e.g. a Product Manager may be incharge of setting up and maintaining the Jira backlog of tickets.
#
# You will be provided with a dataset that will allow you to develop and backtest your strategy. This dataset will provide you with all of the relevant data for a number of years. Your strategy will then be tested on a different timeframe to determine it's profitability (Profit/Loss).
#
# It may be useful to begin the task by trying to understand the 'bigger picture' of how each component of the project would come together i.e the strategy itself, the risk management system, the data and your testing systems.
#
# You will be provided with an initial template to set out the fundamental components of your system, but you can feel free to expand on these as you wish. However, you need to be wary that your strategy **MUST** still be able to be backtested through the function included below. Please **DO NOT** modify this function in any way.
#
# We have seperated your teams to include Analysts of different disciplines, skills and interests. You should capitalise on this to allow everyone to contribute to the project in the best way that they can.
#
# Some example roles you may want to have (you do not have to stick to these) :
#
# - Software Engineer
# - Quant Researcher
# - Quant Developer
# - Algo Engineer
# - Data Scientist
# - Product Manager
#
# Information Links:
#
# - [Investopedia - Forex Trading](https://www.investopedia.com/terms/f/foreign-exchange.asp)
# - [Investopedia - Forex (Definitions, How To and Examples)](https://www.investopedia.com/terms/f/forex.asp)
# - [CME Group British Pound GBP/USD Overview](https://www.cmegroup.com/markets/fx/g10/british-pound.html)
# - [Yahoo Finance GBP/USD Live Charts](https://finance.yahoo.com/quote/GBPUSD=X?p=GBPUSD=X&.tsrc=fin-srch)
# - [Yahoo Finance USD/GBP Live Charts](https://finance.yahoo.com/quote/GBP=X?p=GBP=X&.tsrc=fin-srch)
#
# #### Rules:
#
# Here are some rules to simplify this task.
#
# - You can only buy your positions in GBP and sell your positions in USD.
# - You can not leverage or borrow money to buy a position (no negative balances). If your wallet goes to 0 then something is wrong.
# - You can not sell a position you do not have (no shorting)
# - When selling a position, you must sell all of the lots within that position. You can not off-load part of your position.
#
#
# **What is a standard lot in Forex?**
#
# A standard lot in Forex is equal to **100,000 currency units**. It’s the standard unit size for traders, whether independent or institutional.
#
# If the GBP/USD exchange rate was $1.3000, one standard lot of the base currency (GBP) would be 130,000 units. This means, at the current price, you’d need 130,000 units of the quote currency (USD) to buy 100,000 units of GBP.
#
# ---

# %% [markdown]
# ### Datasets
#
# Under this section you will find that two initial datasets are being loaded to be used for this project. These datasets are:
#
# - GBP/USD Historical Prices between 01/01/2010 - 31/12/2020 (Daily)
# - USD/GBP Historical Prices between 01/01/2010 - 31/12/2020 (Daily)
#
# Through your research, you may also find that other datasets across the internet may prove useful in your strategy e.g. Geopolitical data, other currency pairs etc. Feel free to use such datasets to help improve your strategy if you would like to do so.

# %% [markdown]
# ## Importing some popular packages that you may find useful

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from enum import Enum
from datetime import datetime
import uuid 
import string

# %%
complete_gbp_usd_dataset = pd.read_csv('data/GBPUSD_2010_2022.csv')
complete_gbp_usd_dataset.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close  Volume
# 0  2010-01-01  1.618202  1.618202  1.613111  1.613294   1.613294     0.0
# 1  2010-01-04  1.613710  1.623904  1.606503  1.611370   1.611370     0.0
# 2  2010-01-05  1.611863  1.615587  1.597010  1.599079   1.599079     0.0
# 3  2010-01-06  1.599360  1.606323  1.594388  1.602384   1.602384     0.0
# 4  2010-01-07  1.602205  1.605858  1.590078  1.593397   1.593397     0.0

# %%
complete_usd_gbp_dataset = pd.read_csv('data/USDGBP_2010_2022.csv')
complete_usd_gbp_dataset.head()
# Out:
#          Date     Open     High      Low    Close  Adj Close  Volume
# 0  2010-01-01  0.61797  0.61992  0.61797  0.61985    0.61985     0.0
# 1  2010-01-04  0.61969  0.62247  0.61580  0.62059    0.62059     0.0
# 2  2010-01-05  0.62040  0.62617  0.61897  0.62536    0.62536     0.0
# 3  2010-01-06  0.62525  0.62720  0.62254  0.62407    0.62407     0.0
# 4  2010-01-07  0.62414  0.62890  0.62272  0.62759    0.62759     0.0

# %% [markdown]
# ## Simple Moving Average (SMA) strat

# %%
data = pd.DataFrame(complete_gbp_usd_dataset) # Create data frame
data['SMA30'] = data['Open'].rolling(30).mean()  # Calculate 30 day Simple Moving Average of opening prices and add to frame
open_prices = data['Open'] # Extract open, close and date columns
close_prices = data['Close']
dates = data['Date']
data.dropna(inplace=True) # Drop rows with NaN values

def get_sma(prices, rate): # Calculate Simple Moving Average
    return prices.rolling(rate).mean()

data['SMA20'] = get_sma(close_prices, 20)
data['SMA20'].head()
# Out:
# 29    1.600863
# 30    1.598004
# 31    1.594575
# 32    1.591742
# 33    1.588662
# Name: SMA20, dtype: float64

# %% [markdown]
# ## Mean reversion strat

# %%
timeframe = 30
threshold_buy = -0.01
threshold_sell= 0.01

data['SMA30'] = get_sma(close_prices, 30)
data['percent_distance'] = ((data['Close']-data['SMA30'])/data['SMA30']) # Calculate percentage distance from SMA
data['signal'] = 0 # Initialise signal column

data.loc[data['percent_distance'] <= threshold_buy, 'signal']= 1 # Assign buy signal when percentage distance is below or equal to buy threshold
data.loc[data['percent_distance'] >= threshold_sell, 'signal']= -1 # Assign sell signal when percentage distance is above or below to the sell threshold

data.head()
# Out:
#           Date      Open      High       Low     Close  Adj Close  Volume  \
# 29  2010-02-11  1.561402  1.571685  1.556590  1.570204   1.570204     0.0
# 30  2010-02-12  1.570204  1.573886  1.558701  1.569809   1.569809     0.0
# 31  2010-02-15  1.567890  1.571907  1.561792  1.566711   1.566711     0.0
# 32  2010-02-16  1.566637  1.579554  1.563257  1.579005   1.579005     0.0
# 33  2010-02-17  1.578906  1.581778  1.566907  1.568209   1.568209     0.0
#
#        SMA30     SMA20  percent_distance  signal
# 29  1.604256  1.600863         -0.021226       1
# 30  1.602806  1.598004         -0.020587       1
# 31  1.601318  1.594575         -0.021611       1
# 32  1.600649  1.591742         -0.013522       1
# 33  1.599509  1.588662         -0.019569       1

# %% [markdown]
# ### Portfolio
#
# Under this section you will find the boiler plate code for this task. This includes a class named 'portfolio' which will house key data around your trades such as your budget (monetary portfolio), net profit/loss, current positions and number of trades executed etc.
#
# Each time you run a backtest of your strategy, this object will be reinstatiated and repopulated with the latest backtest results.
#
# You **MUST NOT** modify this code in any way. If you suspect there is a bug, please let us know and we will look into resolving it.

# %% [markdown]
# ## All of the backend code. DO NOT CHANGE THIS SECTION IN ANY WAY.

# %%
INITIAL_WALLET_CASH = 5000000
STANDARD_LOT = 100000

class Side(Enum):
    BUY = 'BUY'
    SELL = 'SELL'
    
class Currency(Enum):
    GBP = 'GBP'
    USD = 'USD'
    
class Position:
    def __init__(self,
                 date:datetime,
                 size:int,
                 price,
                 currency:Currency,
                 side:Side):
        
        self._id = str(uuid.uuid4())
        self._date = date
        self._currency = currency
        self._price = price
        self._size = size
        self._side = side
        
class Order:
    def __init__(self,
                 position:Position):
        self._id = str(uuid.uuid4())
        self._position = position
    
    def describe(self):
        return f"<Order id: {self._id} position: {self._position}>"

class Portfolio:
    
    def __init__(self):
        self.cash_wallet = INITIAL_WALLET_CASH  # wallet is in GBP
        self.current_positions = {}
        self.closed_positions = {}
    
    def add_position(self,position):
        self.current_positions[position._id] = position
        self.deduct_from_wallet(self.calculate_deduction(position))
                
    def sell_position(self,position:Position):
        self.current_positions.pop(position._id)
        self.closed_positions[position._id] = position
    
    def get_wallet_value(self):
        return self.cash_wallet
    
    def deduct_from_wallet(self,amount):
        self.cash_wallet -= amount
        
    def add_to_wallet(self,amount):
        self.cash_wallet += amount
        
    def calculate_fees(self,position:Position):
        fee = position._size * 2 #broker fee is £2 per standard lot 
        print("FEE CHARGED: £",fee)
        return fee 
    
    def calculate_total_cost_in_gbp(self,position:Position):
        if(position._currency == Currency.GBP):
            return position._price * (position._size * STANDARD_LOT)
        # elif(position._currency == Currency.USD):
        #     return position._price * current_gbp_price  * (position._size * 100000) # x100000 for standard lot

    def calculate_deduction(self,position):
        return self.calculate_total_cost_in_gbp(position) + self.calculate_fees(position)

# %% [markdown]
# ## You can edit from this point onwards

# %%
## You can implement your strategy in this function.
## Feel free to create additional functions and call them from within the 'strategy' function
## As show in the example below, your function must return a dictionary of orders. 
## These orders will be run through the backtesting function
def strategy(data):
    period = 16
    factor = 3.0
    calculate_ATR(data, period)
    calculate_super_values(data, factor)
    FIXED_LOT_SIZE = 1
    orders = {}
    
    for _, row in data.iterrows():
        date = datetime.strptime(str(row["Date"]), '%Y-%m-%d').date()
        generateSignals(data)
        
        if row['signal'] == 1 and len(orders) <= 500: 
            #if we have money available in the wallet, we can buy
            buy_position = Position(date, FIXED_LOT_SIZE, row.Open, Currency.GBP, Side.BUY)
            buy_order = Order(buy_position)
            orders[buy_order._id] = buy_order

        if row['signal'] == -1  and len(orders) <= 1000:
            sell_position = Position(date, FIXED_LOT_SIZE, row.Open, Currency.GBP, Side.SELL)
            sell_order = Order(sell_position)
            orders[sell_order._id] = sell_order

    return orders
        
def calculate_ATR(data, period):
    data['High-Low'] = data['High'] - data['Low'] # Calculate difference between high and low prices of each day
    data['High-PrevClose'] = abs(data['High'] - data['Close'].shift(1)) # Calculate absolute difference between high price of each day and closing price of previous day
    data['Low-PrevClose'] = abs(data['Low'] - data['Close'].shift(1)) # Calculate absolute difference between low price of each day and closing price of previous day
    
    data['TrueRange'] = data[['High-Low', 'High-PrevClose', 'Low-PrevClose']].max(axis=1) # Calculate the True Range as the maximum of the above three values for each day
    data['ATR'] = data['TrueRange'].rolling(window=period).mean() # Calculate rolling mean of the true True Range values over the time period

def calculate_super_values(data, factor):
    data['basic_upper_band'] = ((data['High'] + data['Low']) / 2 + (factor * data['ATR']))
    data['basic_lower_band'] = ((data['High'] + data['Low']) / 2 - (factor * data['ATR']))
    
    data['supertrend_direction'] = np.where(data['Close'] > data['basic_lower_band'], 1, -1)
    data['supertrend_value'] = np.where(data['supertrend_direction'] == 1, data['basic_lower_band'], data['basic_upper_band'])

def generateSignals(data):
    data['signal'] = 0

    # Buy signal: Price crosses above Supertrend line from below
    buy_condition = (data['Close'] > data['supertrend_value']) & (data['Close'].shift(1) <= data['supertrend_value'].shift(1))
    data.loc[buy_condition, 'signal'] = 1

    # Sell signal: Price crosses below Supertrend line from above
    sell_condition = (data['Close'] < data['supertrend_value']) & (data['Close'].shift(1) >= data['supertrend_value'].shift(1))
    data.loc[sell_condition, 'signal'] = -1
    
    return data

# %% [markdown]
# ## Backtesting function

# %%
# You can use this function to backtest your strategy 
# The function will call your strategy and then execute the orders in the sequence you made them
# Once all of your orders have been completed, you will be shown your final wallet amount and your Profit/Loss.
data_profit_list = []

def local_backtest_strategy(data):
    
    # Initialising the portfolio. £5,000,000 cash and no positions. 
    portfolio = Portfolio()
    order_queue = strategy(data) #calls your function to get all of the orders
    
    for _, order in order_queue.items():
        data_profit_list.append(portfolio.cash_wallet - INITIAL_WALLET_CASH)
        if order._position._side == Side.BUY:
            # if you have enough cash, you can make the purchase 
            if portfolio.calculate_total_cost_in_gbp(order._position) <= portfolio.cash_wallet:
                portfolio.add_position(order._position)
                print(f"BUY ORDER FILLED : (ID) {str(order._id).upper()}")
            else: 
                print("BOOK CASH IS INSUFFICIENT")
                
        if order._position._side == Side.SELL:
            # finding the position we want to sell from our current positions within portfolio
            matching_position  = next((position for position in portfolio.current_positions.values()
                                   if position._side == Side.BUY 
                                   and position._size == order._position._size 
                                   and position._price < order._position._price
                                   and position._date < order._position._date)
                                   ,None)
            
            if matching_position != None:
                sale_earning = order._position._price * (order._position._size * STANDARD_LOT) 
                portfolio.add_to_wallet(sale_earning)
                portfolio.sell_position(matching_position)
                print(f"SELL ORDER FILLED : (ID) {str(order._id).upper()}")
            else:
                print("NO MATCHING POSITION FOUND")
    
    print("ALL ORDERS HAVE BEEN FILLED.")
    print("BOOK CASH LEVEL:", ("£%.2f" % portfolio.cash_wallet))
    
    pnl = portfolio.cash_wallet - INITIAL_WALLET_CASH 
    
    if pnl < 0:
        print("TOTAL LOSS",("£%.2f" % abs(pnl)))
    else:
        print("TOTAL PROFIT",("£%.2f" % pnl))

local_backtest_strategy(data)
# Out:
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 8DD06411-3D60-4F41-87BF-BAF0FDCA4E2F
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) B22E26F9-05BB-4DFC-B336-E9C076965BD3
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F75E0BD5-CFAE-4B76-B2FD-7D2A8CA59477
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) AD93F399-C03F-46A7-AE3A-ACF1ADD0EC4E
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID)
# SELL ORDER FILLED : (ID) 67D387FE-E4E7-4A26-A31D-99AED1AA4D04
# SELL ORDER FILLED : (ID) 40B49F85-6EC5-460D-A19F-AC8E99096DA9
# SELL ORDER FILLED : (ID) A45E330A-2AFD-4F85-AFCA-8C8432B40B10
# SELL ORDER FILLED : (ID) C5EF6FA7-C304-42E9-8731-A75744A81F2F
# SELL ORDER FILLED : (ID) 654E1C09-BF94-4F44-A42C-B509B48DCAB6
# SELL ORDER FILLED : (ID) B6A61179-29D7-4A5F-A3E9-A36BEAEAA8D2
# SELL ORDER FILLED : (ID) BB98C265-0BED-4FAC-910B-F764B472A011
# SELL ORDER FILLED : (ID) 3511988E-1333-446C-9832-FAB4702F3413
# SELL ORDER FILLED : (ID) EA47AEFA-0AA4-4AC4-AEC5-FBAD0890FC20
# SELL ORDER FILLED : (ID) 75E0BD6E-8703-4B07-B416-8AD8B68315B5
# SELL ORDER FILLED : (ID) E55066AB-1E31-4AA0-B6CC-80812135825C
# SELL ORDER FILLED : (ID) 48E7A771-8103-4BE6-B395-0C3B52499749
# SELL ORDER FILLED : (ID) 7F54C1D5-5CF8-4C1F-966B-250C7A2E6BAF
# SELL ORDER FILLED : (ID) C78BEFE4-4BFA-4EC2-8B18-ACC25D9C2701
# SELL ORDER FILLED : (ID) C648A98D-3020-46FA-B28D-3A0C984B0974
# SELL ORDER FILLED : (ID) C68BA072-8F46-4023-ACAB-DBEAE4D17485
# SELL ORDER FILLED : (ID) 77EAF1BA-A254-4FF9-9B7A-FF16E64AA9BA
# SELL ORDER FILLED : (ID) D974B89F-04B0-4CD8-9326-A60C454AEC94
# SELL ORDER FILLED : (ID) FE0F0CFE-86AC-4C7C-9CB6-2EA855D7E541
# SELL ORDER FILLED : (ID) FFF06FCD-BCE3-4F33-BBAE-A0DB83250A23
# SELL ORDER FILLED : (ID) AAAD3380-31AF-4D1F-ADDE-782431F40401
# SELL ORDER FILLED : (ID) 47F57F2C-BD7F-405B-B5CF-B1DD07250B2B
# SELL ORDER FILLED : (ID) EEFC51D5-8327-4ED7-AAD5-BFAD818B862A
# SELL ORDER FILLED : (ID) 91C3C11A-ACC0-46AD-A8BC-99802E5ECC66
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 643C1DCF-E738-44AF-9CF5-F3118221C300
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) FBE6BC03-9A64-41DF-9708-A1A5BE778EBB
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 74634942-1236-4B56-B215-7257B39D51AF
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 610D1483-EC58-4CEB-AC9D-6D79190E0E35
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F2AB522D-6905-446D-B00D-8DC77E821A06
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F113CB28-A35F-4E89-A57D-B0FC438EB60B
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 5A929EB1-DA00-4730-A553-6E49A246B07C
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 8ABB1B67-835D-4F28-B37C-B669665B206D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) A36A6DAF-95C4-428C-AED2-C68D7C561151
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 09816D01-6941-4008-9389-B8AFBE739FE9
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 697FBC49-06CF-44D9-BAEE-832486747323
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 74E7DD7F-50F6-49BC-B5C3-F1E257512F15
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 815FE855-65E0-4536-BC72-8CD07FDA01EF
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 1B17989D-B11E-46D7-9E38-915912432328
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F1295AD0-E95B-49C3-B009-029A74EC85D0
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) E2CEDFCC-AD46-4F05-8955-C0E63C2ACEFC
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F637FFCB-98CB-40E3-AFEB-3F4893656C55
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 1BDB86F0-2B99-4A48-A110-E0A429634CB1
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 8B7ACF8C-D894-49E0-93E1-8A767314C6B7
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) ADFB117D-AC5A-4B38-A412-7589FB402EF1
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 9BB3C410-236E-4BF9-8319-ADF8E60C9865
# SELL ORDER FILLED : (ID) F88B7194-7955-42B7-A114-BB8BEE7F5948
# SELL ORDER FILLED : (ID) C8C5BA3E-AF8A-4158-BC1E-B7134310A5BF
# SELL ORDER FILLED : (ID) 6F7FF04F-7752-4282-816D-5E7D0B07A05A
# SELL ORDER FILLED : (ID) B0229B06-BD36-406F-A819-EE81D602FB06
# SELL ORDER FILLED : (ID) 35FA4B41-A07C-46E1-A1DE-9053DB5B4B9A
# SELL ORDER FILLED : (ID) A9F8D9C8-1DFF-4E65-9B01-8AA3083E4173
# SELL ORDER FILLED : (ID) 1048C722-61F9-430F-BA08-DA1AC38D7C6F
# SELL ORDER FILLED : (ID) 615FF805-550D-4A1E-9B3A-14133A0AA540
# SELL ORDER FILLED : (ID) 52294CE0-0334-40DF-9652-C31D9784672C
# SELL ORDER FILLED : (ID) EA9A599B-CE8B-470C-ACED-FFC6D86AFE4E
# SELL ORDER FILLED : (ID) DF9C78C7-3C07-4063-9E8A-10579DB45564
# SELL ORDER FILLED : (ID) 3BB26A3B-E7DB-4095-B159-B7F2BD179E73
# SELL ORDER FILLED : (ID) 0D933C7A-EEE8-4DAB-9294-70F527998772
# SELL ORDER FILLED : (ID) 65E92F46-9814-4DDD-8391-76BBC8DF2252
# SELL ORDER FILLED : (ID) 03B6DECB-11A7-4A09-A797-A45492647081
# SELL ORDER FILLED : (ID) 0B0C4222-542A-49C6-AD8F-CF9ED0F57B24
# SELL ORDER FILLED : (ID) 0764EC9F-17F0-421C-AE0D-88E8C4E84371
# SELL ORDER FILLED : (ID) FC0398E0-C529-4BFA-859D-92C38D542C71
# SELL ORDER FILLED : (ID) F6FC344D-9912-4B31-847B-72A3CEDBC943
# SELL ORDER FILLED : (ID) 2226553B-7FAF-44D6-A4F5-751A7D6E496E
# SELL ORDER FILLED : (ID) E7DF93DC-9C09-4C29-B34A-D177B7A3721B
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) C97318F7-C474-40D4-B133-0513F4500EA0
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 86A4FD7F-56DC-4677-9749-9B7BC38B9C6C
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 205F6345-7652-4011-861F-3FC0AB6FEA56
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 7DDC7838-2573-4EB3-8893-C45D0F36A769
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 413449C6-9B0C-458D-9272-CB850E48A8B9
# SELL ORDER FILLED : (ID) 26F1476D-3648-446D-B8DF-51FD0E5A337E
# SELL ORDER FILLED : (ID) 101F3FCE-B82B-412D-92CA-60CC1C325CAB
# SELL ORDER FILLED : (ID) 7A1FD3B5-A57B-4A55-BE68-B1F579F42FE0
# SELL ORDER FILLED : (ID) F0BAF492-133B-4428-86B1-6A178D036166
# SELL ORDER FILLED : (ID) 20180D77-9CC4-4F17-B104-94A8BE520B44
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID)
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 28007BF6-2300-4B96-9268-BBBED2A79E6C
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 8480F2CF-3E07-498C-BC67-69DB5D1413DF
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) EFE2A3B0-CD98-441B-B14B-8B3FF926434B
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) CC12AC4A-1213-472A-B6D6-86EBDC8F3C60
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 4F7A77C4-5E8F-4E99-BC8E-5E423DF9071D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 90C993D3-F1D5-4A6D-A230-CE35A84D4812
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 40D9A6F1-502A-45C1-93B6-79471B43FA4E
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 5179DFB3-264C-4AE6-9591-72529B8EEBF1
# SELL ORDER FILLED : (ID) 3EB85133-0B1A-49EB-A430-842F983255D5
# SELL ORDER FILLED : (ID) 8A095AF8-7A23-49EB-8828-332697E0BC45
# SELL ORDER FILLED : (ID) 67DBA426-657F-4640-9EAB-DB0E220462FB
# SELL ORDER FILLED : (ID) 8BF22066-4323-4555-AEB2-EEF01093200F
# SELL ORDER FILLED : (ID) 5CE9F62E-463D-4158-9A66-1F86E6C55DCC
# SELL ORDER FILLED : (ID) 1FD4E716-C609-400B-9F41-5CFEBFF40830
# SELL ORDER FILLED : (ID) 889EDC1F-146C-4F97-A8A4-CF69D12A9B7C
# SELL ORDER FILLED : (ID) A36BBD04-8F91-4ED6-9F9A-3237F80EAF0D
# SELL ORDER FILLED : (ID) 3309B0AE-99D8-4982-B076-365F4DB13718
# SELL ORDER FILLED : (ID) 4BB8FB7A-828B-461B-9095-BD71A0B7CBA3
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F81D38D2-39F7-4E59-94D8-1EA31C8BE126
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 02BA8E70-9FE7-4AC8-9851-35B28B89363C
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 7FDDC6F3-5759-4C10-BFC0-F38393BCF699
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 17FCE1C7-C71D-4C03-89F1-D4764A9BE0C2
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) B4D5AEB7-FD19-4570-B1A4-A0480C6477DB
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 042B82F3-6E82-409A-8BF4-1A9D383F5F4E
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) C3020F53-F725-402C-83EE-8787DA85D081
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 22F621F2-CEC2-4B62-8CFA-897CB591FE1D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 3288D495-9781-4B2D-A079-35668A3C96D8
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) AC3B3C1A-6FD0-491D-9A45-057747EA6C4F
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 656E4AFC-970C-47D7-88CC-7038AE578283
# SELL ORDER FILLED : (ID) 064A8226-1C66-4EEC-84B6-A4EA7453DE2E
# SELL ORDER FILLED : (ID) 8BEE76E8-84F4-4437-B3EF-DABF28495042
# SELL ORDER FILLED : (ID) 2F5A3930-01FC-4710-BF40-A0F96A3924E0
# SELL ORDER FILLED : (ID) 5B885892-06C0-44DE-9D0F-77782290AC16
# SELL ORDER FILLED : (ID) FCBEEB9A-4564-4BCF-87CA-C1BD5B8A0406
# SELL ORDER FILLED : (ID) C659BDB5-C2F4-492A-8F09-38583E9BED5A
# SELL ORDER FILLED : (ID) EA6D83AF-5BEC-4A1D-9888-84F2C874D100
# SELL ORDER FILLED : (ID) A79BCF08-607E-4B07-B18A-F15473AAABCB
# SELL ORDER FILLED : (ID) 606DEA36-1D5D-41E5-95FD-06C73191938C
# SELL ORDER FILLED : (ID) 59D685CC-C11F-4070-A998-3436040A033E
# SELL ORDER FILLED : (ID) 68AB765F-4171-4FDA-BF95-EA99238EF598
# SELL ORDER FILLED : (ID) 216F7946-8DAB-4947-9F94-4357B7D4F7CF
# SELL ORDER FILLED : (ID) 214AF6D0-74F3-4D9D-9D38-0671DC3CA4A6
# SELL ORDER FILLED : (ID) 62D2BD22-27A0-4424-A177-8F26D0FF89AE
# SELL ORDER FILLED : (ID) BD924015-8B7F-449C-A9D7-BA6ED658FE90
# SELL ORDER FILLED : (ID) EEF01C5D-B4AA-4FF0-986A-896A611CD0DE
# SELL ORDER FILLED : (ID) D981A41B-0F93-4B23-A3A4-110F257A2958
# SELL ORDER FILLED : (ID) 804535C1-6774-4E60-95F6-6886C0A6915B
# SELL ORDER FILLED : (ID) 3E5D9BEA-171D-4BE0-9EFE-039D2C6A2CAE
# SELL ORDER FILLED : (ID) E4529D1C-8972-48FA-B8B5-10A70C623BDD
# SELL ORDER FILLED : (ID) 5BD6C917-79D7-46DD-8F78-A73CDACD29B4
# SELL ORDER FILLED : (ID) 86FFD0BA-4EFA-4A30-873D-6D2EEEA19F99
# SELL ORDER FILLED : (ID) CF18E943-A5BA-46A4-82C5-7B179343B8B5
# SELL ORDER FILLED : (ID) 765D81D9-9A12-4AB2-B1B0-641491459A13
# SELL ORDER FILLED : (ID) DB2058B4-ECC9-4C84-BA0C-695BE09137E2
# SELL ORDER FILLED : (ID) 8C05BC04-49D6-47E8-88AA-CF490731C8B1
# SELL ORDER FILLED : (ID) AEE13907-3B07-4326-9FC8-88C59F03DB82
# SELL ORDER FILLED : (ID) 89CF5D08-CA62-4012-BF4E-76458C0C791D
# SELL ORDER FILLED : (ID) B43CF20B-25CC-4B93-A507-FC23800B3F98
# SELL ORDER FILLED : (ID) BCA8EE67-9303-4029-8616-6A3F1F0379F0
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# ALL ORDERS HAVE BEEN FILLED.
# BOOK CASH LEVEL: £5766385.40
# TOTAL PROFIT £766385.40

# %% [markdown]
# ## Data Analysis and Research
#
# You can include all of your data analysis and research under this section. Maybe some cool charts and formulas too?

# %%
plot = data[['Close', 'SMA20']].plot(label='GBP/USD', figsize=(32,16))
plot.set_ylabel("Price (GBP/USD)")

data_profit = pd.DataFrame(data_profit_list)

# %% [markdown]
# ## Risk Management
#
# You can include your risk management process and functions (code) under this section.

# %%
def risk_manager(data, risk_per_trade=0.02, stop_loss_factor=2):
    
    # Calculate position size based on risk per trade
    data['position_size'] = (data['ATR'] * risk_per_trade) / data['Close']
    
    # Calculate stop-loss levels based on stop-loss factor
    data['stop_loss'] = data['Close'] - (data['ATR'] * stop_loss_factor)
    
    return data

# %%
plt.figure(figsize=(20, 12))
plt.plot(data_profit[0], label ='Accumulated Profit', color='blue')

plt.title('Running Profit')
plt.xlabel('Number of orders since January 28th, 2010')
plt.ylabel('Pounds')
plt.legend()
