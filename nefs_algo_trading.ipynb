# %% [markdown]
# # NEFS Technology Division - Algorithmic Trading Project Template

# %% [markdown]
# ### Description
#
# As a group, you have been tasked with researching, implementing and testing a profitable Foreign Exchange (Forex) trading strategy. The pair you have been assigned is GBP/USD.
#
# Each group will have a number of Quants, Software Engineers and Product Managers. You will need to work as a team to allocate responsibilities for the duration of the project. e.g. a Product Manager may be incharge of setting up and maintaining the Jira backlog of tickets.
#
# You will be provided with a dataset that will allow you to develop and backtest your strategy. This dataset will provide you with all of the relevant data for a number of years. Your strategy will then be tested on a different timeframe to determine it's profitability (Profit/Loss).
#
# It may be useful to begin the task by trying to understand the 'bigger picture' of how each component of the project would come together i.e the strategy itself, the risk management system, the data and your testing systems.
#
# You will be provided with an initial template to set out the fundamental components of your system, but you can feel free to expand on these as you wish. However, you need to be wary that your strategy **MUST** still be able to be backtested through the function included below. Please **DO NOT** modify this function in any way.
#
# We have seperated your teams to include Analysts of different disciplines, skills and interests. You should capitalise on this to allow everyone to contribute to the project in the best way that they can.
#
# Some example roles you may want to have (you do not have to stick to these) :
#
# - Software Engineer
# - Quant Researcher
# - Quant Developer
# - Algo Engineer
# - Data Scientist
# - Product Manager
#
# Information Links:
#
# - [Investopedia - Forex Trading](https://www.investopedia.com/terms/f/foreign-exchange.asp)
# - [Investopedia - Forex (Definitions, How To and Examples)](https://www.investopedia.com/terms/f/forex.asp)
# - [CME Group British Pound GBP/USD Overview](https://www.cmegroup.com/markets/fx/g10/british-pound.html)
# - [Yahoo Finance GBP/USD Live Charts](https://finance.yahoo.com/quote/GBPUSD=X?p=GBPUSD=X&.tsrc=fin-srch)
# - [Yahoo Finance USD/GBP Live Charts](https://finance.yahoo.com/quote/GBP=X?p=GBP=X&.tsrc=fin-srch)
#
# #### Rules:
#
# Here are some rules to simplify this task.
#
# - You can only buy your positions in GBP and sell your positions in USD.
# - You can not leverage or borrow money to buy a position (no negative balances). If your wallet goes to 0 then something is wrong.
# - You can not sell a position you do not have (no shorting)
# - When selling a position, you must sell all of the lots within that position. You can not off-load part of your position.
#
#
# **What is a standard lot in Forex?**
#
# A standard lot in Forex is equal to **100,000 currency units**. It’s the standard unit size for traders, whether independent or institutional.
#
# If the GBP/USD exchange rate was $1.3000, one standard lot of the base currency (GBP) would be 130,000 units. This means, at the current price, you’d need 130,000 units of the quote currency (USD) to buy 100,000 units of GBP.
#
# ---

# %% [markdown]
# ### Datasets
#
# Under this section you will find that two initial datasets are being loaded to be used for this project. These datasets are:
#
# - GBP/USD Historical Prices between 01/01/2010 - 31/12/2020 (Daily)
# - USD/GBP Historical Prices between 01/01/2010 - 31/12/2020 (Daily)
#
# Through your research, you may also find that other datasets across the internet may prove useful in your strategy e.g. Geopolitical data, other currency pairs etc. Feel free to use such datasets to help improve your strategy if you would like to do so.

# %%
#importing some popular packages that you may find useful

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from enum import Enum
from datetime import datetime
import uuid 
import string

# %%
complete_gbp_usd_dataset = pd.read_csv('GBPUSD_2010_2022.csv')
complete_usd_gbp_dataset = pd.read_csv('USDGBP_2010_2022.csv')

complete_gbp_usd_dataset
complete_usd_gbp_dataset
# Out:
#             Date      Open     High      Low     Close  Adj Close  Volume
# 0     2010-01-01  0.617970  0.61992  0.61797  0.619850   0.619850     0.0
# 1     2010-01-04  0.619690  0.62247  0.61580  0.620590   0.620590     0.0
# 2     2010-01-05  0.620400  0.62617  0.61897  0.625360   0.625360     0.0
# 3     2010-01-06  0.625250  0.62720  0.62254  0.624070   0.624070     0.0
# 4     2010-01-07  0.624140  0.62890  0.62272  0.627590   0.627590     0.0
# ...          ...       ...      ...      ...       ...        ...     ...
# 3386  2022-12-26  0.829187  0.82960  0.82671  0.829187   0.829187     0.0
# 3387  2022-12-27  0.827570  0.83310  0.82561  0.827530   0.827530     0.0
# 3388  2022-12-28  0.831410  0.83310  0.82480  0.831440   0.831440     0.0
# 3389  2022-12-29  0.831050  0.83226  0.82810  0.831360   0.831360     0.0
# 3390  2022-12-30  0.829420  0.83245  0.82598  0.829440   0.829440     0.0
#
# [3391 rows x 7 columns]

# %%
data = pd.DataFrame(complete_gbp_usd_dataset) # Create data frame
data['SMA30'] = data['Open'].rolling(30).mean()  # Calculate 30 day Simple Moving Average of opening prices and add to frame

open_prices = data['Open'] # Extract open, close and date columns
close_prices = data['Close']
dates = data['Date']

data.dropna(inplace=True) # Drop rows with NaN values

def get_sma(prices, rate): # Calculate Simple Moving Average
    return prices.rolling(rate).mean()

data['SMA20'] = get_sma(close_prices,20)

data

##Mean Reversion
timeframe = 30
threshold_buy = -0.01
threshold_sell= 0.01

data['sma'] = data['Close'].rolling(window=timeframe).mean() # Calculate SMA of closing prices

data['percent_distance'] = ((data['Close']-data['sma'])/data['sma']) # Calculate percentage distance from SMA

data['signal'] = 0 # Initialise signal column

data.loc[data['percent_distance'] <= threshold_buy, 'signal']= 1 # Assign buy signal when percentage distance is below or equal to buy threshold

data.loc[data['percent_distance'] >= threshold_sell, 'signal']= -1 # Assign sell signal when percentage distance is above or below to the sell threshold

data
##Volatility
# Out:
#             Date      Open      High       Low     Close  Adj Close  Volume  \
# 29    2010-02-11  1.561402  1.571685  1.556590  1.570204   1.570204     0.0
# 30    2010-02-12  1.570204  1.573886  1.558701  1.569809   1.569809     0.0
# 31    2010-02-15  1.567890  1.571907  1.561792  1.566711   1.566711     0.0
# 32    2010-02-16  1.566637  1.579554  1.563257  1.579005   1.579005     0.0
# 33    2010-02-17  1.578906  1.581778  1.566907  1.568209   1.568209     0.0
# ...          ...       ...       ...       ...       ...        ...     ...
# 3386  2022-12-26  1.206001  1.209614  1.205400  1.206001   1.206001     0.0
# 3387  2022-12-27  1.208357  1.211226  1.200336  1.208415   1.208415     0.0
# 3388  2022-12-28  1.202776  1.212415  1.200336  1.202733   1.202733     0.0
# 3389  2022-12-29  1.203297  1.207584  1.201548  1.202848   1.202848     0.0
# 3390  2022-12-30  1.205662  1.210683  1.201273  1.205633   1.205633     0.0
#
#          SMA30     SMA20       sma  percent_distance  signal
# 29    1.605970  1.600863       NaN               NaN       0
# 30    1.604370  1.598004       NaN               NaN       0
# 31    1.602842  1.594575       NaN               NaN       0
# 32    1.601335  1.591742       NaN               NaN       0
# 33    1.600653  1.588662       NaN               NaN       0
# ...        ...       ...       ...               ...     ...
# 3386  1.209123  1.217352  1.209097         -0.002560       0
# 3387  1.210226  1.217971  1.210202         -0.001477       0
# 3388  1.210715  1.218374  1.210692         -0.006574       0
# 3389  1.211095  1.218129  1.211069         -0.006788       0
# 3390  1.211752  1.217114  1.211723         -0.005026       0
#
# [3212 rows x 12 columns]

# %% [markdown]
# ### Portfolio
#
# Under this section you will find the boiler plate code for this task. This includes a class named 'portfolio' which will house key data around your trades such as your budget (monetary portfolio), net profit/loss, current positions and number of trades executed etc.
#
# Each time you run a backtest of your strategy, this object will be reinstatiated and repopulated with the latest backtest results.
#
# You **MUST NOT** modify this code in any way. If you suspect there is a bug, please let us know and we will look into resolving it.

# %% [markdown]
# ## All of the backend code. DO NOT CHANGE THIS SECTION IN ANY WAY.

# %%
INITIAL_WALLET_CASH = 5000000
STANDARD_LOT = 100000

class Side(Enum):
    BUY = 'BUY'
    SELL = 'SELL'
    
class Currency(Enum):
    GBP = 'GBP'
    USD = 'USD'
    
class Position:
    def __init__(self,
                 date:datetime,
                 size:int,
                 price,
                 currency:Currency,
                 side:Side):
        
        self._id = str(uuid.uuid4())
        self._date = date
        self._currency = currency
        self._price = price
        self._size = size
        self._side = side
        
class Order:
    def __init__(self,
                 position:Position):
        self._id = str(uuid.uuid4())
        self._position = position
    
    def describe(self):
        return f"<Order id: {self._id} position: {self._position}>"

class Portfolio:
    
    def __init__(self):
        self.cash_wallet = INITIAL_WALLET_CASH  # wallet is in GBP
        self.current_positions = {}
        self.closed_positions = {}
    
    def add_position(self,position):
        self.current_positions[position._id] = position
        self.deduct_from_wallet(self.calculate_deduction(position))
                
    def sell_position(self,position:Position):
        self.current_positions.pop(position._id)
        self.closed_positions[position._id] = position
    
    def get_wallet_value(self):
        return self.cash_wallet
    
    def deduct_from_wallet(self,amount):
        self.cash_wallet -= amount
        
    def add_to_wallet(self,amount):
        self.cash_wallet += amount
        
    def calculate_fees(self,position:Position):
        fee = position._size * 2 #broker fee is £2 per standard lot 
        print("FEE CHARGED: £",fee)
        return fee 
    
    def calculate_total_cost_in_gbp(self,position:Position):
        if(position._currency == Currency.GBP):
            return position._price * (position._size * STANDARD_LOT)
        # elif(position._currency == Currency.USD):
        #     return position._price * current_gbp_price  * (position._size * 100000) # x100000 for standard lot

    def calculate_deduction(self,position):
        return self.calculate_total_cost_in_gbp(position) + self.calculate_fees(position)

# %% [markdown]
# ## You can edit from this point onwards

# %%
## You can implement your strategy in this function.
## Feel free to create additional functions and call them from within the 'strategy' function
## As show in the example below, your function must return a dictionary of orders. 
## These orders will be run through the backtesting function
def strategy(data):
    
    period = 16
    factor = 3.0
    
    calculateATR(data, period)

    calculateSuperValues(data, factor)

    FIXED_LOT_SIZE = 1
    
    orders = {}

    print(data['signal'])
    
    for index,row in data.iterrows():
        date = datetime.strptime(str(row["Date"]),'%Y-%m-%d').date()
        generateSignals(data)
        
        if(row['signal'] == 1 and len(orders) <= 500): 
            
            
            #if we have money available in the wallet, we can buy
            buy_position = Position(date,FIXED_LOT_SIZE,row.Open,Currency.GBP,Side.BUY)
            buy_order = Order(buy_position)
            orders[buy_order._id] = buy_order
    
        if(row['signal'] == -1  and len(orders) <= 1000):
            sell_position = Position(date,FIXED_LOT_SIZE,row.Open,Currency.GBP,Side.SELL)
            sell_order = Order(sell_position)
            orders[sell_order._id] = sell_order

    return orders
        
def calculateATR(data, period):

    data['High-Low'] = data['High'] - data['Low'] # Calculate difference between high and low prices of each day
    data['High-PrevClose'] = abs(data['High'] - data['Close'].shift(1)) # Calculate absolute difference between high price of each day and closing price of previous day
    data['Low-PrevClose'] = abs(data['Low'] - data['Close'].shift(1)) # Calculate absolute difference between low price of each day and closing price of previous day
    data['TrueRange'] = data[['High-Low', 'High-PrevClose', 'Low-PrevClose']].max(axis=1) # Calculate the True Range as the maximum of the above three values for each day

    data['ATR'] = data['TrueRange'].rolling(window=period).mean() # Calculate rolling mean of the true True Range values over the time period

def calculateSuperValues(data, factor):

    data['basic_upper_band'] = ((data['High'] + data['Low']) / 2 + (factor * data['ATR']))

    data['basic_lower_band'] = ((data['High'] + data['Low']) / 2 - (factor * data['ATR']))

    data['supertrend_direction'] = np.where(data['Close'] > data['basic_lower_band'], 1, -1)

    data['supertrend_value'] = np.where(data['supertrend_direction'] == 1, data['basic_lower_band'], data['basic_upper_band'])

   

    

def generateSignals(data):

    data['signal'] = 0

    # Buy signal: Price crosses above Supertrend line from below
    buy_condition = (data['Close'] > data['supertrend_value']) & (data['Close'].shift(1) <= data['supertrend_value'].shift(1))
    data.loc[buy_condition, 'signal'] = 1

    # Sell signal: Price crosses below Supertrend line from above
    sell_condition = (data['Close'] < data['supertrend_value']) & (data['Close'].shift(1) >= data['supertrend_value'].shift(1))
    data.loc[sell_condition, 'signal'] = -1

    return data

# %%
# You can use this function to backtest your strategy 
# The function will call your strategy and then execute the orders in the sequence you made them
# Once all of your orders have been completed, you will be shown your final wallet amount and your Profit/Loss.
dataProfitList = []

def local_backtest_strategy(data):
    
    # Initialising the portfolio. £5,000,000 cash and no positions. 
    portfolio = Portfolio()
    order_queue = strategy(data) #calls your function to get all of the orders
    
    for index,order in order_queue.items():

        dataProfitList.append(portfolio.cash_wallet - INITIAL_WALLET_CASH)
    
        if(order._position._side == Side.BUY):
            # if you have enough cash, you can make the purchase 
            if portfolio.calculate_total_cost_in_gbp(order._position) <= portfolio.cash_wallet:
                portfolio.add_position(order._position)
                print(f"BUY ORDER FILLED : (ID) {str(order._id).upper()}")
            else: 
                print("BOOK CASH IS INSUFFICIENT")
                
        if(order._position._side == Side.SELL):
            # finding the position we want to sell from our current positions within portfolio
            matching_position  = next((position for position in portfolio.current_positions.values()
                                   if position._side == Side.BUY 
                                   and position._size == order._position._size 
                                   and position._price < order._position._price
                                   and position._date < order._position._date)
                                   ,None)
            
            if(matching_position != None):
                sale_earning = order._position._price * (order._position._size * STANDARD_LOT) 
                portfolio.add_to_wallet(sale_earning)
                portfolio.sell_position(matching_position)
                print(f"SELL ORDER FILLED : (ID) {str(order._id).upper()}")
            else:
                print("NO MATCHING POSITION FOUND")
    
    print("ALL ORDERS HAVE BEEN FILLED.")
    print("BOOK CASH LEVEL:", ("£%.2f" % portfolio.cash_wallet))
    
    pnl = portfolio.cash_wallet - INITIAL_WALLET_CASH 
    
    if(pnl < 0):
        print("TOTAL LOSS",("£%.2f" % abs(pnl)))
    else:
        print("TOTAL PROFIT",("£%.2f" % pnl))

local_backtest_strategy(data)
# Out:
# 29      0
# 30      0
# 31      0
# 32      0
# 33      0
# BOOK CASH IS INSUFFICIENT
# BOOK CASH IS INSUFFICIENT
# BOOK CASH IS INSUFFICIENT
# BOOK CASH IS INSUFFICIENT
# BOOK CASH IS INSUFFICIENT
# SELL ORDER FILLED : (ID) 0ABD1887-D05A-451F-A7A9-515BFAFD96AB
# SELL ORDER FILLED : (ID) F65CD5E2-552B-4AA5-A879-E14C70ED8018
# SELL ORDER FILLED : (ID) 7BE474EF-DDD2-4302-B27F-B9A7FDA1CF43
# SELL ORDER FILLED : (ID) D55FC8FD-4991-48C2-969B-47FF20D8BDD8
# SELL ORDER FILLED : (ID) CE32D09A-88DD-49F1-B791-0EB54EAE7373
# SELL ORDER FILLED : (ID) 57CD2A73-EF98-4214-A928-BC5786AF82A8
# SELL ORDER FILLED : (ID) 2A2F0D6D-7863-4C36-8B71-372FA02561C8
# SELL ORDER FILLED : (ID) 39590EF0-F3B8-4FB4-90ED-CFA5F217FA46
# SELL ORDER FILLED : (ID) 4962D790-6768-4FAD-A60C-795BDACD9F6F
# SELL ORDER FILLED : (ID) 805872D0-8F27-41B7-ABF4-8548CB870EC3
# SELL ORDER FILLED : (ID) 30E723AC-EB5B-40A8-A97B-A3F0FF970F76
# SELL ORDER FILLED : (ID) F7FD3AC2-C1A8-4D01-B760-EBFD25F39B68
# SELL ORDER FILLED : (ID) D780EB1E-65CE-4B04-8975-431F302B91D0
# SELL ORDER FILLED : (ID) DB9ACB25-15BF-4C91-913C-ACDB60529FE4
# SELL ORDER FILLED : (ID) 3B47B86F-B350-4B87-8763-B4115166C630
# SELL ORDER FILLED : (ID) B169C5A7-B48C-4D6B-9F6A-40CE42D6AF52
# SELL ORDER FILLED : (ID) 2C0884C0-6819-416C-969D-19719BC905B4
# SELL ORDER FILLED : (ID) 6C446B3A-5EE7-4B5B-973A-89F7051C1D2F
# SELL ORDER FILLED : (ID) FFD1B119-48D2-4623-A296-4DB6B3388401
# SELL ORDER FILLED : (ID) 6113E081-2B06-4A36-B867-7112D27E88C9
# SELL ORDER FILLED : (ID) D43D4F08-87B7-48A1-80C3-DCB7E3E34C48
# SELL ORDER FILLED : (ID) E1D4C72E-0D82-4A11-85D6-028AED62212C
# SELL ORDER FILLED : (ID) 7C9ADFA4-2ED7-4FAE-8C07-71DC7483767B
# SELL ORDER FILLED : (ID) 50B96C03-8F2E-4A9E-A16C-86F1E5DE5535
# SELL ORDER FILLED : (ID) F4E8DB64-0446-4197-A970-9CE15A4522CE
# SELL ORDER FILLED : (ID) B5CA23AB-0FD7-4ADC-BABE-C857D3CDAEFD
# SELL ORDER FILLED : (ID) B8205909-3CB4-4214-BD70-3B739D5A0996
# SELL ORDER FILLED : (ID) B5B02919-68EB-4DF1-BC3B-351B4C3ADE38
# SELL ORDER FILLED : (ID) 15F93EAA-AE3D-45D9-AE5C-BDFEFD066559
# SELL ORDER FILLED : (ID) 39DA5A1D-C581-43BE-A1B2-9349C174B3AE
# SELL ORDER FILLED : (ID) 1D66402B-96A9-48DC-A61E-D3C3924501F6
# SELL ORDER FILLED : (ID) 410A014A-6092-4C20-8569-17B1477648F2
# SELL ORDER FILLED : (ID) EE99A2C0-D5C2-4B4E-A364-C7EC81FE5834
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 47149A43-075A-43D3-8EE8-06A88E1ECBFE
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) DD8871C4-0FC9-4981-8AF4-6551B51F55ED
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 69D8F6BE-52EA-4228-A011-8EDE7337D563
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 496FC1FF-B6F8-4868-A6F6-D35EF01AC512
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 9A5ED9A8-DD6C-4AA3-9EBB-477A7B5EC718
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 2D1B23D0-E944-4B0C-B0BE-094A776940C3
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 59FEF351-FEF4-426D-BDF2-FAAF256F40E3
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) DA730F76-175B-4405-AD9A-815C3BF3988F
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 1C62FDD2-F64B-4BA6-9071-D09F56354E9E
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) E90DE0E9-1B4D-4810-802A-66126E5EE55A
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) D1BF3DC7-33E0-4567-A0A7-51B6A6E26D53
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) A8E99E62-EB3F-41D3-9B59-FE90F07A3F35
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 37E4323C-0687-446E-BB70-26B3ED0372BB
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 8417842E-B6BE-4D9A-9A9B-4B133343F49D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) EB27FE39-5F85-4EF7-9A37-C4C8C422011D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 610AC933-6B0D-46B7-AE10-229084BF4C3A
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) EB55365F-FD72-4AFB-8113-40029B072EEB
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) AD2B4EA6-B221-460B-ABC5-717A52B41074
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 3F9E4264-F29D-4869-A5BD-315114BFA039
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F931779A-F262-4924-9DC1-DD027025D4B0
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 623E0CA9-3928-43BB-AF8C-208E9B7B2D5F
# SELL ORDER FILLED : (ID) D7798557-5DB4-4735-B33A-E7846A529F50
# SELL ORDER FILLED : (ID) 7FDF9B29-8FCE-4787-B97F-EC480CCEB793
# SELL ORDER FILLED : (ID) C56675B4-8E45-4937-AE53-439CAB0A70EB
# SELL ORDER FILLED : (ID) B438BFA1-2CFF-43A1-9B0D-67E02F5008EA
# SELL ORDER FILLED : (ID) 73BC8A0E-118E-4D61-B194-63B470173595
# SELL ORDER FILLED : (ID) DBA5FE21-7C7B-456B-8CFB-6714F8C55E2B
# SELL ORDER FILLED : (ID) 8ED34CE8-3EBD-4879-8DE7-95AEEF160790
# SELL ORDER FILLED : (ID) BACCDDC3-4F36-4D10-993C-6CDBC873415C
# SELL ORDER FILLED : (ID) 2E84E994-8CD8-49B4-AE9F-88F9FC39C3E0
# SELL ORDER FILLED : (ID) CFA490E4-7C7F-4A40-BA01-4E2F35286AEE
# SELL ORDER FILLED : (ID) F3229542-D7CE-4FE8-BDC7-866F99F11326
# SELL ORDER FILLED : (ID) B99B4A68-C6FD-419F-BFF7-22A8F7BDA6BE
# SELL ORDER FILLED : (ID) 06D43D0E-4D93-4F8A-8C3C-95D89B820274
# SELL ORDER FILLED : (ID) E29E7582-4693-47D5-9C5B-597C313A6724
# SELL ORDER FILLED : (ID) D71B75BF-762B-4174-866B-1E70555585F9
# SELL ORDER FILLED : (ID) 2CFF285C-D664-4ADB-A3D7-D263739B9D1F
# SELL ORDER FILLED : (ID) 618BFCBC-ED8B-4FD2-8A3A-ACAC14053B72
# SELL ORDER FILLED : (ID) 7E30C56C-CC7F-4AF7-A99F-08A4AE368AF4
# SELL ORDER FILLED : (ID) 0FA2FBF5-A727-4EE7-99EB-01527601C7FF
# SELL ORDER FILLED : (ID) EABDF97E-B8D8-4F91-B345-43CAF5E8C82F
# SELL ORDER FILLED : (ID) 66BB6D0D-7EA6-4F1E-85C8-7B463592EBAF
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 1ACEA5C4-A60D-47A4-98DC-851EB066082A
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 448A5BD1-BCF7-40C4-820A-510220E6ABE9
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 96256AFA-626C-40E5-ACC7-361BE2F51DFD
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 34EF1D42-458A-4DE4-8870-70083D42210B
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID)
# SELL ORDER FILLED : (ID) EC98B006-586B-480B-9C7A-9606D15DBED3
# SELL ORDER FILLED : (ID) 88563122-0BAE-43F0-AF5D-4B877A64D3BA
# SELL ORDER FILLED : (ID) 04831482-352A-4DB2-BA4D-805B03FCB937
# SELL ORDER FILLED : (ID) 6A4A202F-DFEA-4E8B-A5ED-EB3A0A5745B2
# SELL ORDER FILLED : (ID) B5FD255E-0A75-4441-9A5D-84260C324671
# SELL ORDER FILLED : (ID) 2AAD003F-0078-41EA-9361-3B2F56991D36
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 7BFF64C0-173F-49E6-B24F-1D36EF26B631
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) D8F44FA6-3585-4702-8882-C13B5DF6F43D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 4FF75D90-3F27-430C-8853-37B37C9A0FFA
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 65393128-464C-4FE8-8C69-A3F0767A8B22
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 208D17D7-D9AC-4696-A44D-D3B978F6B5D8
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) EB9602B6-ED6A-47AF-875E-8A72F20B5E96
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) EADEB472-19DE-490D-ADAA-9AD2E3EDA7B9
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 9C324305-7155-44E0-917E-E8546F8BADD7
# SELL ORDER FILLED : (ID) 8E0BA807-1E2F-4411-AC81-DDF3B2F7F942
# SELL ORDER FILLED : (ID) 9824A278-2BFB-4097-A4A5-CF25FDE4526F
# SELL ORDER FILLED : (ID) BE66A838-C4EC-40BE-A87B-6CE1239F6C03
# SELL ORDER FILLED : (ID) BFE13B87-AEC4-460B-B98E-0BA41C022DC4
# SELL ORDER FILLED : (ID) 4CE7A905-685F-4502-B393-C9B8CE306338
# SELL ORDER FILLED : (ID) AA00E049-4DB5-48C5-811A-7EC4DE7C180D
# SELL ORDER FILLED : (ID) CF4AFD5E-0629-4D48-A8A9-4A88BBD06C99
# SELL ORDER FILLED : (ID) 71CF31E9-A567-498D-A757-6EDD3F51B990
# SELL ORDER FILLED : (ID) 4EBB82AF-9F4D-47E1-9226-1986F693EDB8
# SELL ORDER FILLED : (ID) 59655698-0939-4D26-AA66-BE325F82577E
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) D3EF2055-15CF-4641-990A-4E811B0500AD
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F5551E32-B6E3-4502-88C8-3171C0FD6F32
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 362A78E0-F707-4706-9E40-396D691E295D
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) ED82454D-2285-47F4-8B9B-5B8FEF1BE7BA
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) EBDA5F89-66B4-4B4A-A1FC-B56CB5936370
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 9F3B541B-8268-4C94-8051-7A578444BE6F
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 28956722-5EDF-469E-AF68-EFB242844987
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F14C7A88-C3F6-4B9F-B56A-F1D4D9D6757C
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) F0FACDC4-C972-48EE-B4BE-938478EACA98
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) E62AB9CA-8BC1-4124-9390-A44C5C4641D0
# FEE CHARGED: £ 2
# BUY ORDER FILLED : (ID) 87B5B512-5EC2-49B1-AF4A-E841BE1F9F75
# SELL ORDER FILLED : (ID) EF9F56F3-67E5-4760-8E56-5E0C80EB162C
# SELL ORDER FILLED : (ID) 6FD3BB34-060B-4FEE-9610-F662BBB0EA5E
# SELL ORDER FILLED : (ID) 25862326-E939-4C17-8B1A-B364C990A83A
# SELL ORDER FILLED : (ID) C757DFBA-2212-4AB3-9BCE-289ECD116647
# SELL ORDER FILLED : (ID) D04BDA6A-AF1B-4A65-8C13-8C7171EC7C75
# SELL ORDER FILLED : (ID) FF1103BE-281E-4E75-8F8C-B38CBEC92AE8
# SELL ORDER FILLED : (ID) 06ADBFA7-D056-440A-ADE3-13C299E8F467
# SELL ORDER FILLED : (ID) 5198D661-1409-4898-B44A-1D472C0B8AAB
# SELL ORDER FILLED : (ID) 49C9193C-F356-44AE-8441-684FBC8A37B5
# SELL ORDER FILLED : (ID) 8037911B-C295-4105-AE54-CD0A44A31371
# SELL ORDER FILLED : (ID) D0FA7F3C-1464-4984-8B79-D367522FA79E
# SELL ORDER FILLED : (ID) ED0A35CE-76E5-47F1-B876-C7EA7DB0D1E5
# SELL ORDER FILLED : (ID) 393327D7-C875-42D8-9820-9EA944E1463D
# SELL ORDER FILLED : (ID) 8AB67C28-936D-41C2-9AF5-C21BFE520150
# SELL ORDER FILLED : (ID) 90D64737-B946-430C-92D4-560ECCCD3639
# SELL ORDER FILLED : (ID) 71D3E339-F190-46C9-8548-971564352955
# SELL ORDER FILLED : (ID) 7C0E8598-0149-4384-AA37-887A28A21001
# SELL ORDER FILLED : (ID) 65F488FB-3372-497D-B6BA-CC9334A88FCE
# SELL ORDER FILLED : (ID) 604521B4-A9F2-4D0E-AD22-703807B47930
# SELL ORDER FILLED : (ID) AC375661-E283-41FB-B97E-D3B004216820
# SELL ORDER FILLED : (ID) BA4544D6-396F-4647-AAC9-8EB573A93E4A
# SELL ORDER FILLED : (ID) E5F87634-DE5D-4740-BF65-14D972FC6A5A
# SELL ORDER FILLED : (ID) E5227AA4-3269-46F6-9BBB-DD9458F191CE
# SELL ORDER FILLED : (ID) 814E83E8-AB87-45A9-8F27-042909B611AF
# SELL ORDER FILLED : (ID) D043B631-DFA3-4728-AA70-F188518DF546
# SELL ORDER FILLED : (ID) 48877E29-098D-4DA2-8CCE-E6900AF3A7DB
# SELL ORDER FILLED : (ID) FA44995B-3B1B-4D9D-B82E-2A29AB216D15
# SELL ORDER FILLED : (ID) AAA42F40-8A0F-4A7B-9CDC-070EC5254FB0
# SELL ORDER FILLED : (ID) 307354B4-486A-4474-9ABF-BBFF3526D404
# SELL ORDER FILLED : (ID) BA563D81-AEE4-4572-8B63-B9DAC16E7138
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# NO MATCHING POSITION FOUND
# ALL ORDERS HAVE BEEN FILLED.
# BOOK CASH LEVEL: £5768510.10
# TOTAL PROFIT £768510.10

# %% [markdown]
# ## Data Analysis and Research
#
# You can include all of your data analysis and research under this section. Maybe some cool charts and formulas too?

# %%
plot = data[['Close', 'SMA20']].plot(label='GBP/USD',figsize=(32,16))
plot.set_ylabel("Price (GBP/USD)")

dataProfit = pd.DataFrame(dataProfitList)

# %% [markdown]
# ## Risk Management
#
# You can include your risk management process and functions (code) under this section.

# %%
def risk_manager(data, risk_per_trade=0.02, stop_loss_factor=2):
    
    # Calculate position size based on risk per trade
    data['position_size'] = (data['ATR'] * risk_per_trade) / data['Close']
    
    # Calculate stop-loss levels based on stop-loss factor
    data['stop_loss'] = data['Close'] - (data['ATR'] * stop_loss_factor)
    
    return data

# %%
plt.figure(figsize=(20, 12))
plt.plot(dataProfit[0], label ='Accumulated Profit', color='blue')

plt.title('Running Profit')
plt.xlabel('Number of orders since January 28th, 2010')
plt.ylabel('Pounds')
plt.legend()
